# %%
import pandas as pd
import clase_funciones_EDA
from clase_funciones_EDA import funciones_EDA

# %%
air = pd.read_csv('Air_Quality_20231023.csv')
air.head(2)
# Out:
#    Unique ID  Indicator ID        Name  ...  Start_Date Data Value Message
# 0     216498           386  Ozone (O3)  ...  06/01/2013      34.64     NaN
# 1     216499           386  Ozone (O3)  ...  06/01/2014      33.22     NaN
#
# [2 rows x 12 columns]

# %%
air.shape
# Out:
# (16122, 12)

# %%
instancia = funciones_EDA()

# %%
resultado = instancia._3_view_data_by_types(air)
# Out:
# NOMBRE COLUMNA:  Unique ID
#                                0
# Tipo Dato          <class 'int'>
# Cant. Valores              16122
# % en Columna              100.0%
# Cant. Val. Únicos          16122
# % de únicos               100.0%
#
# Valores únicos: [216498 216499 219969 ... 671120 671121 671122]
#
#
# -------------------------------------------------------------
# NOMBRE COLUMNA:  Indicator ID
#                                0
# Tipo Dato          <class 'int'>
# Cant. Valores              16122
# % en Columna              100.0%
# Cant. Val. Únicos             22
# % de únicos                0.14%
#
# Valores únicos: [386 383 639 640 641 642 646 647 648 650 651 643 652 653 655 657 659 661
#  644 645 375 365]
#
#
# -------------------------------------------------------------
# NOMBRE COLUMNA:  Name
#                                0
# Tipo Dato          <class 'str'>
# Cant. Valores              16122
# % en Columna              100.0%
# Cant. Val. Únicos             19
# ...

# %%
resultado = instancia._5_view_unique_value_percent(air)
# Out:
#            Cantidad  Porcentaje (%)
# Unique ID
# 216498            1            0.01
# 164882            1            0.01
# 130364            1            0.01
# 130363            1            0.01
# 130362            1            0.01
# ...             ...             ...
# 671117            1            0.01
# 671118            1            0.01
# 671119            1            0.01
# 671120            1            0.01
# 671122            1            0.01
#
# [16122 rows x 2 columns]
# -------------------------------------------------------------
#               Cantidad  Porcentaje (%)
# Indicator ID
# 365               5076           31.48
# 375               5076           31.48
# 386               1692           10.49
# 383               1128            7.00
# 644                214            1.33
# 643                209            1.30
# 645                209            1.30
# 655                192            1.19
# 648                192            1.19
# ...

# %% [markdown]
# LA COLUMNA MESSAGE DEBE ELIMINARSE NO APORTA NINGUN VALOR ESTA TOTALMENTE NULA

# %% [markdown]
# LAS 11 COLUMNAS RESTANTES APORTAN INFORMACION VALIOSA RESPECTO DE LA CANTIDAD DE EMISIONES DE VARIOS GASES NOCIVOS
